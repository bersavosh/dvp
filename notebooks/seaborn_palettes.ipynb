# %% [markdown]
# # Seaborn palettes

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# %%
# Load an example dataset
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = sns.relplot(data=tips,
                  x="total_bill", y="tip", col="time",
                  hue="smoker", style="smoker", size="size")

# %% [markdown]
# ## Palette
#
# We can inspect and use available color palettes with `color_palette`.
#
# Calling with no arguments returns all colors from the current default color cycle:

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %% [markdown]
# Possible `palette` values include:
# ### Name of a seaborn palette
#
# (`deep`, `muted`, `bright`, `pastel`, `dark`, `colorblind`)

# %%
for i in ['deep', 'muted', 'bright', 'pastel', 'dark', 'colorblind']:
    print(i)
    palette = sns.color_palette(i)
    display(palette)
# Out:
# deep
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]
# muted
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
# ...

# %% [markdown]
# ### Name of known matplotlib, seaborn, HUSL, Color Brewer colormaps
#
# (*to return a specified number of evenly spaced colors*)

# %%
for i in ['flare','viridis','bwr','husl','hls','Set1']:
    print(i,'(discrete)')
    palette = sns.color_palette(i,n_colors=10)
    display(palette)
    print(i,'(continuous)')
    palette = sns.color_palette(i,as_cmap=True)
    display(palette)
# Out:
# flare (discrete)
# [(0.92118373, 0.60184659, 0.45048789),
#  (0.910403, 0.51342591, 0.39932342),
#  (0.89260152, 0.42376366, 0.36526813),
#  (0.85754536, 0.33574168, 0.36373567),
#  (0.79876118, 0.27347974, 0.39064559),
#  (0.71837612, 0.24102046, 0.41863486),
#  (0.63329016, 0.21816454, 0.43555493),
#  (0.54585987, 0.19467771, 0.44234111),
#  (0.46073893, 0.17645017, 0.43417097),
#  (0.37562649, 0.15974704, 0.41151182)]
# flare (continuous)
# viridis (discrete)
# [(0.283072, 0.130895, 0.449241),
#  (0.262138, 0.242286, 0.520837),
#  (0.220057, 0.343307, 0.549413),
#  (0.177423, 0.437527, 0.557565),
#  (0.143343, 0.522773, 0.556295),
#  (0.119512, 0.607464, 0.540218),
#  (0.166383, 0.690856, 0.496502),
#  (0.319809, 0.770914, 0.411152),
#  (0.525776, 0.833491, 0.288127),
#  (0.762373, 0.876424, 0.137064)]
# viridis (continuous)
# bwr (discrete)
# [(0.1803921568627451, 0.1803921568627451, 1.0),
#  (0.3607843137254902, 0.3607843137254902, 1.0),
# ...

# %% [markdown]
# As you can see, `Set1` is a qualitative (discrete) color palette, and thus even as a colormap it appears as such.

# %% [markdown]
# ### a customized cubehelix color palette
#
# `ch:<cubehelix arguments>`

# %%
print('(discrete)')
palette = sns.color_palette("ch:s=.25,rot=-.25",n_colors=10)
display(palette)
print('(continuous)')
palette = sns.color_palette("ch:s=.25,rot=-.25", as_cmap=True)
display(palette)
# Out:
# (discrete)
# [(0.7801075672866592, 0.8741945391838343, 0.9197573835143084),
#  (0.6847390181296589, 0.7972569622186081, 0.8795061917757581),
#  (0.602184906961236, 0.714507477800132, 0.8354795932180334),
#  (0.5305747875017413, 0.6275172490416577, 0.7843516199526199),
#  (0.4674057490345695, 0.5380526944752408, 0.7234739258377286),
#  (0.41247971599718325, 0.45247764741142626, 0.6549040023597509),
#  (0.35679566827085535, 0.3636031988077555, 0.5704475191345615),
#  (0.2997996175567367, 0.2777651223237753, 0.47328314356469137),
#  (0.2378945598761033, 0.19664357974385346, 0.3642090794357591),
#  (0.1676124288206785, 0.12168378009569247, 0.24493209028077442)]
# (continuous)

# %% [markdown]
# ### a light-themed sequential colormap to a seed color

# %%
print('(discrete)')
palette = sns.color_palette("light:#5A9",n_colors=10)
display(palette)
print('(continuous)')
palette = sns.color_palette("light:#5A9", as_cmap=True)
display(palette)
# Out:
# (discrete)
# [(0.9219374658653965, 0.9498758137297091, 0.9423834457343508),
#  (0.8573064238618758, 0.9187783387580809, 0.9047884007125397),
#  (0.7926753818583552, 0.8876808637864527, 0.8671933556907288),
#  (0.7257360883547088, 0.8554727647086949, 0.8282556304895672),
#  (0.661105046351188, 0.8243752897370668, 0.7906605854677562),
#  (0.5941657528475417, 0.792167190659309, 0.7517228602665946),
#  (0.529534710844021, 0.7610697156876808, 0.7141278152447836),
#  (0.46259541734037457, 0.728861616609923, 0.6751900900436221),
#  (0.3979643753368539, 0.6977641416382948, 0.6375950450218111),
#  (0.3333333333333333, 0.6666666666666666, 0.6)]
# (continuous)

# %% [markdown]
# #### How do we use these for visualization?
#
# - For seaborn defaults, we can just pass the name.
# - For ones we have made, we can pass the produced `sns.color_palette` to `set_palette` or `set_theme(palette='...')`

# %%
palt = sns.color_palette("pastel")
display(palt)
sns.set_palette(palt)

# Above is equivalent of:
#sns.set_theme(palette=palt)

fig = sns.relplot(data=tips,
                  x="total_bill", y="tip", col="time",
                  hue="smoker", style="smoker", size="size")
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
palt = sns.color_palette("hot",n_colors=2,desat=1)
display(palt)
sns.set_palette(palt)

# Above is equivalent of:
#sns.set_theme(palette=palt)

fig = sns.relplot(data=tips,
                  x="total_bill", y="tip", col="time",
                  hue="smoker", style="smoker", size="size")
# Out:
# [(0.9166617446269619, 0.0, 0.0), (1.0, 0.7916663385421999, 0.0)]
