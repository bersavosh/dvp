# %% [markdown]
# # Seaborn and matplotlib fonts

# %%
# Import seaborn
import seaborn as sns
import matplotlib
from IPython.core.display import HTML

# %%
# Load an example dataset
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Fonts in a theme
#
# Default is sans-serif font

# %%
sns.set_theme(font='sans-serif')
# above is equivalent to
#sns.set_theme()

fig = sns.relplot(data=tips,
                  x="total_bill", y="tip", col="time",
                  hue="smoker", style="smoker", size="size")

# %%
sns.set_theme(font='serif')
# above is equivalent to
#sns.set_theme()

fig = sns.relplot(data=tips,
                  x="total_bill", y="tip", col="time",
                  hue="smoker", style="smoker", size="size")

# %%
sns.set_theme(font='purisa')

fig = sns.relplot(data=tips,
                  x="total_bill", y="tip", col="time",
                  hue="smoker", style="smoker", size="size")

# %% [markdown]
# ## Here is a fancy way of seeing a list of all available fonts to matplotlib on a system:

# %%
def html_display(fontname):
    return f"<p>{fontname}: <span style='font-family:{fontname}; font-size: 24px;'>{fontname}</p>"

fontobject_list = matplotlib.font_manager.fontManager.ttflist

fontname_list = sorted(set([fontobject.name for fontobject in fontobject_list]))


code = "\n".join([html_display(font) for font in fontname_list])

HTML("<div style='column-count: 3;'>{}</div>".format(code))
# Out:
# <div style='column-count: 3;'><p>Abyssinica SIL: <span style='font-family:Abyssinica SIL; font-size: 24px;'>Abyssinica SIL</p>
# <p>Andale Mono: <span style='font-family:Andale Mono; font-size: 24px;'>Andale Mono</p>
# <p>Ani: <span style='font-family:Ani; font-size: 24px;'>Ani</p>
# <p>AnjaliOldLipi: <span style='font-family:AnjaliOldLipi; font-size: 24px;'>AnjaliOldLipi</p>
# <p>Arial: <span style='font-family:Arial; font-size: 24px;'>Arial</p>
# <p>Arial Black: <span style='font-family:Arial Black; font-size: 24px;'>Arial Black</p>
# <p>Chandas: <span style='font-family:Chandas; font-size: 24px;'>Chandas</p>
# <p>Chilanka: <span style='font-family:Chilanka; font-size: 24px;'>Chilanka</p>
# <p>Comic Sans MS: <span style='font-family:Comic Sans MS; font-size: 24px;'>Comic Sans MS</p>
# <p>Courier New: <span style='font-family:Courier New; font-size: 24px;'>Courier New</p>
# ...
